# %% [markdown]
# # Strings

# %% [markdown]
# ### 1. ¿Qué es un string?

# %% [markdown]
# Un **string** se corresponde con un conjunto de caracteres que forman una cadena de texto.
#
# La sintaxis que debemos utilizar para definir strings en Python consiste en situar los caracteres entre `"` o `'`

# %% [markdown]
# La flexibilidad de definir string con el caracter `"` y el caracter `'` nos permite definir cadenas de texto que contienen esos mismos caracteres.

# %%
Nombre
# Out:
# "Jose 'pepe' "

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
#
# ### La función `print()`
#
# Hasta ahora, cada vez que mostrábamos strings por pantalla, estos salían entre comillas simples.
#
# La función `print()` nos sirve, entre otras muchas cosas, para mostrar strings por pantalla.
#
# <div>

# %%
print(Nombre)
# Out:
# Jose 'pepe'

# %% [markdown]
# #### String literals
#
# El hecho de que el contenido de las variables de tipo `str` vaya entre comillas, ya sean simples o dobles, conlleva a que algunos caracteres deban ser tratados de forma especial.
#
# Aquí entran en juego los string literals. Algunos de los más utilizados se muestran en la siguiente tabla:
#
# Código | Significado |
# --- | --- |
# `\\` | Backslash, `\`|
# `\'` | Comilla simple, `'`|
# `\"` | Comilla doble, `"`|
# `\n` | Salto de línea|
# `\t` | Tabulación horizontal|
#
# Para más información acerca de los string literals ir a la [documentación](https://docs.python.org/3.7/reference/lexical_analysis.html#string-and-bytes-literals).

# %%
Nombre="Jose \n pepe "

# %%
print(Nombre)
# Out:
# Jose
#  pepe

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
#
# **Observación.** Si usamos comillas dobles, para guardar la frase de este ejemplo necesitaremos usar string literals, ya que si no nos saltará error. Sin embargo, si usamos comillas simples, para guardar la frase de este ejemplo en una variable no hace falta que cambiemos nada.
#
# <div>

# %% [markdown]
# ### 2. Indexación

# %% [markdown]
# En muchos tipos de datos en Python se puede acceder a elementos individuales de un conjunto ordenado de datos directamente mediante un índice numérico o un valor clave. Este proceso se denomina indexación.
#
# En Python, las cadenas son secuencias ordenadas de caracteres, y por lo tanto pueden ser indexadas de esta manera. Se puede acceder a los caracteres individuales de una cadena especificando el nombre de la cadena seguido de un número entre corchetes `[]`.
#
# El primer carácter de la cadena tiene el índice 0, el siguiente tiene el índice 1, y así sucesivamente. El índice del último carácter será la longitud de la cadena menos uno.

# %%
Elem= "Hola como estas?"

# %%
Elem[2:3]
# Out:
# 'l'

# %%
Salon= "Jose", "Pedro", "Juan"
print(Salon)
# Out:
# ('Jose', 'Pedro', 'Juan')

# %%
Salon[0]
# Out:
# 'Jose'

# %%
Salon[2]
# Out:
# 'Juan'

# %% [markdown]
# Tambien podemos utilizar números negativos para extraer caracteres por el final de la cadena de texto.

# %%
Salon[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-acb461f5603c> in <module>
# ----> 1 Salon[-4]
#
# IndexError: list index out of range

# %%
Salon[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-bfc6109c5740> in <module>
# ----> 1 Salon[-5]
#
# IndexError: list index out of range

# %% [markdown]
# ### 3. Slicing

# %% [markdown]
# Python también permite una sintaxis específica de indexación que extrae subcadenas de una cadena de texto, a esto se denomina **slicing**.
#
# La sintaxis que se utiliza para extraer una subcadena de una cadena `s` es de la forma `s[m:n]`, esto devuelve la porción de `s` que comienza en la posición `m`, y termina en la posición `n` (sin ser incluido el último caracter)

# %%
Salon[1:2]
# Out:
# ['Pedro']

# %%
Salon
# Out:
# ['Jose', 'Pedro', 'Juan']

# %% [markdown]
# Si no indicamos uno de los números, lee hasta el final.

# %%
Salon[:2]
# Out:
# ['Jose', 'Pedro']

# %% [markdown]
# ### 4. Stride

# %% [markdown]
# El stride es otra variante más del slicing. Si se añade un `:` adicional y un tercer índice, se designa una stride, que indica cuantos caracteres saltar hasta obtener el siguiente caracter.

# %%
Salon= "Jose", "Pedro", "Juan", "María", "Ana", "Luisa", "Marta", "Elena"

# %%
Salon[0:8:3]
# Out:
# ('Jose', 'María', 'Marta')

# %% [markdown]
# ### 5. Modificación de strings

# %% [markdown]
# Un string es un tipo de dato que Python considera **inmutable**, esto quiere decir que no podemos modificar una parte de un string asociada a una variable

# %%
Salon
# Out:
# ['Jose', 'Pedro', 'Juan', 'María', 'Ana', 'Luisa', 'Marta', 'Elena']

# %% [markdown]
# A pesar de que no pueda modificarse el contenido de un string, si puede asignarse un string diferente a la variable.

# %%
Salon= ["Jose", "Pedro", "Juan", "María", "Ana", "Luisa", "Martha", "Elena"]
Salon
# Out:
# ['Jose', 'Pedro', 'Juan', 'María', 'Ana', 'Luisa', 'Martha', 'Elena']

# %% [markdown]
# ### 6. Strings de múltiples líneas

# %% [markdown]
# En algunas ocasiones es posible que queramos definir un string que tenga múltiples líneas. Existen varias formas de definir esto en Python.

# %% [markdown]
# La forma más sencilla es introducir el caracter `\n` en la posición de la cadena de texto donde queremos que se produzca el salto de línea.

# %%
Salon= "Jose , Maria, \n Pedro"

# %%
print(Salon)
# Out:
# Jose , Maria,
#  Pedro

# %% [markdown]
# Otra opción interesante es situar nuestra cadena de texto entre los caracteres ```"""```.

# %%
Salon= """Jose , Maria, \n Pedro"""
Salon1= "Jose , Maria, \n Pedro"

# %%
print(Salon)
print(Salon1)
# Out:
# Jose , Maria,
#  Pedro
# Jose , Maria,
#  Pedro

# %% [markdown]
# ### 7. Concatenación de strings
#
# La concatenación es una operación que une dos o más strings en uno solo.
#
# En `Python`, para concatenar dos variables de tipo string usamos la función `+`.

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
#
# **Observación.** La concatenación viene a ser como pegar el final del primer string con el princio del segundo. Entonces, conviene poner un espacio al final de la primera variable a concatenar, o bien al principio de la segunda para que así, al realizar la concatenación, exista ese espacio entre las palabras.
#
# De no añadir espacios adicionales, obtendríamos resultados como el mostrado en el siguiente chunk:
#
# <div>

# %%
Clase1="Jesus, Pedro, "
Clase2="María, Ana, "

# %%
Salon= Clase1 +Clase2

# %%
print(Salon)
# Out:
# Jesus, Pedro, María, Ana

# %% [markdown]
# ### 8. Repetición de strings
#
# La repetición es una operación que repite la variable string tantas veces como indiquemos.
#
# En `Python`, para repetir una variable de tipo string usamos la función `*`. El orden de los factores no altera el producto. Es decir, tanto da usar la sintaxis `num_repeticiones * variable_str` como `variable_str * num__repeticiones`.

# %%
3*Clase1
# Out:
# 'Jesus, Pedro, Jesus, Pedro, Jesus, Pedro, '

# %%
5*(Clase2+Clase1)
# Out:
# 'María, Ana, Jesus, Pedro, María, Ana, Jesus, Pedro, María, Ana, Jesus, Pedro, María, Ana, Jesus, Pedro, María, Ana, Jesus, Pedro, '

# %% [markdown]
# ### 9. La función `str()`
#
# Con la función `str()`, podemos concatenar strings y variables de cualquier tipo dentro de un `print()`:

# %%
Clase1="Jose"
Clase2="Pedro"
Numero=10

# %%
print(Numero)
print(Clase1+str(Numero))
# Out:
# 3
# Jose3

# %%
Numero
# Out:
# 3

# %% [markdown]
# ### 10. El método `.format()`
#
# Existe otra forma de concatenar strings y variables de cualquier tipo dentro de un `print()` y es gracias al método `.format()`. Lo que hay que hacer es indicar con llaves, `{}`, donde queremos situar el resultado de las variables y luego, dentro de los paréntesis del método `.format()`, indicar las variables en su respectivo orden

# %%
Estudiantes="En el salon caben {No} estudiantes"
print(Estudiantes.format(No=no2))
# Out:
# En el salon caben 5 estudiantes

# %%
no2=5

# %% [markdown]
# # Ejercicio
#
# Imprimir por pantalla el siguiente ejemplo:
#
# `Hola mi nombre es Yimmy y tengo 33 años`
#
# Establecer en variables
#
# Año Actual y Fecha de Nacimiento, Nombre.

# %%
Est1="Yimmy"
Edad1=33

Est2="Juan"
Edad2=24

Presentacion= "Hola mi nombre es {PrimerNomb} y tengo {Edad} años"
print(Presentacion.format(PrimerNomb=Est1, Edad=Edad1))
print(Presentacion.format(PrimerNomb=Est2, Edad=Edad2))
# Out:
# Hola mi nombre es Yimmy y tengo 33 años
# Hola mi nombre es Juan y tengo 24 años

# %% [markdown]
# ### 11. Métodos para trabajar con strings

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# El método `.lower()` nos transforma el string que indiquemos a minúsculas.

# %%
Nombre= "JUan12 Andres Paez"

# %%
print(Nombre.lower())
# Out:
# juan12 andres

# %% [markdown]
# El método `.upper()`, por el contrario, lo transforma a mayúsculas.

# %%
print(Nombre.upper())
# Out:
# JUAN12

# %% [markdown]
# El método `.count()` cuenta cuántas veces aparece una letra o un string dentro del string al cuál le aplicamos dicho método.

# %%
print(Nombre.count("a"))
# Out:
# 2

# %% [markdown]
# El método `.capitalize()` convierte a mayúscula el primer caracter de un string.

# %%
Institucion="bigdatave Institución"

# %%
print(Institucion.capitalize())
# Out:
# Bigdatave institución

# %% [markdown]
# El método `.title()` convierte a mayúscula el primer caracter de cada palabra de un string.

# %%
pais= "republica bolivariana de Venezuela"

Presentacion="inspeccion del flujo de migrantes en la frontera colombo-venezolana"

# %%
print(Presentacion.title())
# Out:
# Inspeccion Del Flujo De Migrantes En La Frontera Colombo-Venezolana

# %% [markdown]
# El método `.swapcase()` convierte a mayúscula las minúsculas y viceversa.

# %%
Nombres= "lA CASA DE PAPEL"

# %%
Nombrestransformados= Nombres.swapcase()
print(Nombrestransformados)
# Out:
# La casa de papel

# %% [markdown]
# El método `.replace()` reemplaza el caracter (o caracteres) que le indiquemos por el string que queramos.

# %%
pais= "republica bolivariana de Venezuela"

# %%
nuevopais= pais.replace("bolivariana de","de")

# %%
print(nuevopais)
# Out:
# republica de Venezuela

# %%
nuevopais=nuevopais.title()
print(nuevopais)
# Out:
# Republica De Venezuela

# %% [markdown]
# El método `.split()` rompe el string en el caracter que le indiquemos y elimina dicho caracter.

# %%
pais= pais.split(" ")

# %%
print(pais)
# Out:
# ['republica', 'bolivariana', 'de', 'Venezuela']

# %% [markdown]
# El método `.rstrip()` elimina los espacios sobrantes al final del string.

# %%
pais= "republica bolivariana de Venezuela   "
pais
# Out:
# 'republica bolivariana de Venezuela   '

# %%
print(pais.rstrip())
# Out:
# republica bolivariana de Venezuela

# %% [markdown]
# El método .`lstrip()` elimina los espacios sobrantes al principio del string.

# %%
pais= "   republica bolivariana de Venezuela  "

# %%
print(pais.rstrip().lstrip())
# Out:
# republica bolivariana de Venezuela

# %% [markdown]
# El método `.find()` tiene otros dos parámetros de uso opcional: `start` y `end`, que sirven para indicar donde queremos que empiece la búsqueda y donde queremos que acabe.

# %%
pais= "republica bolivariana de Venezuela"
print(pais.find("a",10))
# Out:
# 15

# %% [markdown]
# El método `.index()` busca el caracter que indiquemos y nos devuelve la primera posición en la que aparece.

# %%
print(pais.index("a"))
# Out:
# 8

# %% [markdown]
# El método `.rindex()` busca el caracter que indiquemos y devuelve el último indice en el que fue encontrado.

# %%
print(pais.rindex("a"))
# Out:
# 33

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
#
# El método `.input()` Esta función permite obtener el texto escrito por el usuario, el cual se asignará a un espacio de memoria con el nombre que el programador vea conveniente.
# <div>

# %%
print("Cuantos compañeros de clases hay en python 1?")
x=input()
print("En python 1 hay "+ x +" compañeros de clase")
# Out:
# Cuantos compañeros de clases hay en python 1?
# 5
# En python 1 hay 5 compañeros de clase

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## Ejercicio 1
# Utiliza las funciones de concatenar, + y repetir strings, *, junto con la función print() para dados los siguientes strings s1, s2, s3 y s4, conseguir el resultado siguiente: Había una vez, un barquito chiquitito
# Había una vez, un barquito chiquitito que no podía, que no podía, que no podía navegar.

# %%
s1 = "Había una vez, "
s2 = "un barquito chiquitito "
s3 = "que no podía, "
s4 = "que no podía navegar."

# %%
print(s1 + s2 + s1 + s2 + s3 + s3 + s4)
# Out:
# Había una vez, un barquito chiquitito Había una vez, un barquito chiquitito que no podía, que no podía, que no podía navegar.

# %% [markdown]
# ## Ejercicio 2
# Utiliza la función `print()` y el comando de salto de línea, \n, para reproducir exactamente el siguiente texto:
#
# Érase un hombre a una nariz pegado,\
# Érase una nariz superlativa,\
# Érase una alquitara medio viva,\
# Érase un peje espada mal barbado;

# %%
k1="Érase un hombre a una nariz pegado,"
k2="Érase una nariz superlativa,"
k3="Érase una alquitara medio viva,"
k4="Érase un peje espada mal barbado;"

kt= k1 +"\n" + k2 +"\n" + k3 +"\n" + k4

print(kt)
print("\n")
print("Érase un hombre a una nariz pegado, \nÉrase una nariz superlativa, \nÉrase una alquitara medio viva, \nÉrase un peje espada mal barbado;")
# Out:
# Érase un hombre a una nariz pegado,
# Érase una nariz superlativa,
# Érase una alquitara medio viva,
# Érase un peje espada mal barbado;
#
#
# Érase un hombre a una nariz pegado,
# Érase una nariz superlativa,
# Érase una alquitara medio viva,
# Érase un peje espada mal barbado;

# %% [markdown]
# ## Ejercicio 3
#
# Vamos a pedirle al usuario palabras o frases y le vamos a devolver el mismo string modificado con alguno de los métodos aprendidos según se indique:
#
# 1. Devolver la palabra en mayúscula
# 2. Devolver la frase con todas las palabras empezando en mayúscula
# 3. Devolver la palabra (con 3 o más letras) con todas las letras en minúscula salvo la tercera letra
# 4. Devolver la palabra con todas las letras en mayúsculas salvo la primera y la última
# 5. Devolver la frase donde cada vez que aparezcan las dos primeras letras de la primera palabra, sean substituidas por cualesquiera otras dos letras.

# %%
Ejercicio= "Palabras a tratar"

# %%
print(Ejercicio.upper())
# Out:
# PALABRAS A TRATAR

# %%
print(Ejercicio.title())
# Out:
# Palabras A Tratar

# %%
t1=(Ejercicio.lower())

# %%
tercercaracter=t1[2:3]
print(tercercaracter)
TercerCaracterMayus=tercercaracter.swapcase()
print(TercerCaracterMayus)
primeraparte=t1[0:2]
print(primeraparte)
segundaparte=t1[3:]
print(segundaparte)
tercermayus=primeraparte+TercerCaracterMayus+segundaparte
print(tercermayus)
# Out:
# l
# L
# pa
# abras a tratar
# paLabras a tratar

# %%
t4=(Ejercicio.upper())
print(t4)
centro=t4[1:-1]
print(centro)
primeraletraminuscula=t4[0:1].swapcase()
print(primeraletraminuscula)
ultimaletraminuscula=t4[-1:].swapcase()
print(ultimaletraminuscula)
#Devolve la palabra con todas las letras en mayúsculas salvo la primera y la última
Mayusmenosprimeryultimo=primeraletraminuscula+centro+ultimaletraminuscula
print(Mayusmenosprimeryultimo)
# Out:
# PALABRAS A TRATAR
# ALABRAS A TRATA
# p
# r
# pALABRAS A TRATAr

# %%
sindosprimerasletras=Ejercicio[2:]
print(sindosprimerasletras)
agregado=input("Ingrese dos letras")
Nuevafrase=agregado+sindosprimerasletras
print(Nuevafrase)
# Out:
# labras a tratar
# Ingrese dos letraskk
# kklabras a tratar

# %% [markdown]
# ## Ejercicio 4
# Vamos a pedirle al usuario su año de nacimiento y el año actual y le vamos a imprimir por pantalla su edad

# %%
Año_nacimiento_usuario=int(input("Introduzca su año de nacimiento"))
Año_Actual=int(input("Introduzca año actual"))
Edad_usuario=Año_Actual-Año_nacimiento_usuario
Texto="Usted tiene {Edad} años"
print(Texto.format(Edad=Edad_usuario))
# Out:
# Introduzca su año de nacimiento1995
# Introduzca año actual2023
# Usted tiene 28 años

# %% [markdown]
# ## Ejercicio 5
# Transforma el siguiente string s a mayúsculas y muéstralo por pantalla con la función print()

# %% [markdown]
# ## Ejercicio 6
# Calcula la longitud del string `t`

# %%
t="uusgiduisfidus"
tamaño=len(t)
print(tamaño)
# Out:
# 14

# %% [markdown]
# ## Ejercicio 7
# Del string `texto` del ejercicio anterior, obtén el substring **luchando** y guárdalo en una variable llamada `s_sub`.
# No vale contar, deberás hallar los índices del substring con el método .find() (o el que mejor consideres) y
# la función len().
# Finalmente, imprime tu resultado por pantalla

# %%
texto="Es necesario seguir luchando por lo que se desea"

# %% [markdown]
# ## Ejercicio 8
# Con la función `input()`, indícale al usuario que introduzco el `nombre`, `apellido`, `edad`, y `ciudad` en donde vive, guarda cada respuesta en una variable.
#
# Luego, imprime por pantalla todos los datos introducidos por el usuario tal y como se muestra en el siguiente ejemplo:
#
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
#
# Yimmy Eman, tiene 33 años y actualmente vive en Caracas.
#
# <div>

# %%
nombre = input("Introduce tu nombre:\n")
apellido = input("Introduce tu apellido:\n")
# Convertir a entero el retorno de la edad. int() o float() para decimales.
edad = int(input("Introduce tu edad:\n"))
ciudad = input("Introduce tu ciudad:\n")


# primera forma de formateo
print("{} {}, tiene {} años y actualmente vive en {}".format(nombre, apellido, edad, ciudad))

# segunda forma de formateo
print(f"{nombre} {apellido}, tiene {edad} años y actualmente vive en {ciudad}")
# Out:
# Introduce tu nombre:
# Yimmy
# Introduce tu apellido:
# Eman
# Introduce tu edad:
# 33
# Introduce tu ciudad:
# Caracas
# Yimmy Eman, tiene 33 años y actualmente vive en Caracas
# Yimmy Eman, tiene 33 años y actualmente vive en Caracas

# %%
edad + 3
# Out:
# 36

# %%
a = "3"

# %%
a
# Out:
# '3'

# %%
int(a)
# Out:
# 3

# %%
type(5.3)
# Out:
# float

# %%
a = 2


if a > 3:
    print("hola")
else:
    print("adios")
# Out:
# adios

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
