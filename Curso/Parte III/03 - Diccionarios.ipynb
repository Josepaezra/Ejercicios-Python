# %% [markdown]
# # Diccionarios

# %% [markdown]
# ### 1. ¿Qué son los diccionarios en Python?

# %% [markdown]
# Los diccionarios son un tipo de dato complejo y particular del lenguaje de programación Python que se corresponden con una colección de elementos clave-valor. Cada elemento clave-valor asocia la clave con un valor determinado.

# %% [markdown]
# Los diccionarios se representan dentro de python con el tipo de dato `dict`. La sintaxis utilizada para definir diccionarios es la siguiente: `{key:value, key2:value2, ..., keyn:valuen}`

# %%
datos = {"nombre": "yimmy", "apellido": "eman", 0:"HEYY"}
print(datos)
print(type(datos))
# Out:
# {'nombre': 'yimmy', 'apellido': 'eman', 0: 'HEYY'}
# <class 'dict'>

# %%
len(datos)
# Out:
# 2

# %%
datos["nombre"]
# Out:
# 'yimmy'

# %%
datos["apellido"]
# Out:
# 'eman'

# %%
datos[0]
# Out:
# 'HEYY'

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
datos
# Out:
# {'nombre': 'yimmy', 'apellido': 'eman'}

# %%
datos.keys()
# Out:
# dict_keys(['nombre', 'apellido', 0])

# %%
datos.values()
# Out:
# dict_values(['yimmy', 'eman', 'HEYY'])

# %%
estructura_de_datos = {
    "datos personales": {"nombre":"yimmy", "apellido": "eman", "edad": 34},
    "productos": ["Apple TV", "Mac Pro", "Iphone", "Apple Watch"]
}

# %%
print(estructura_de_datos)
# Out:
# {'datos personales': {'nombre': 'yimmy', 'apellido': 'eman', 'edad': 34}, 'productos': ['Apple TV', 'Mac Pro', 'Iphone', 'Apple Watch']}

# %%
len(estructura_de_datos)
# Out:
# 2

# %%
estructura_de_datos["datos personales"]["apellido"]+
# Out:
# 'eman Rangel'

# %%
estructura_de_datos["productos"]
# Out:
# ['Apple TV', 'Mac Pro', 'Iphone', 'Apple Watch']

# %%
type(estructura_de_datos["productos"])
# Out:
# list

# %%
estructura_de_datos["productos"][1]
# Out:
# 'Mac Pro'

# %%
ejercicio = {
    
    (1, 2) : [3, 4, 5]
    
}

# %%
ejercicio[(1,2)]
# Out:
# [3, 4, 5]

# %%
# La estructura es key: value y key puede ser cualquier objeto. int, float, complex, list, tuple, dict

# %%
ejercicio = {
    0: {"1": [1,2,3,4], "hola": {"x": [[[5]]]}},
    (1,2,3) : [[6]],
    "final": {"11": {"z": (7,)}}
}

# %%
ejercicio[0]['1'][0]
# Out:
# 1

# %%
a = int(a)
type(a)

# %%
# Otra forma de definir diccionarios con la funcion dict()
dic2 = dict(
    Nombre="Yimmy",
    Apellido="Eman",
    Pais="Venezuela",
    Ciudad="Caracas"
)

# %%
print(dic2)

# %% [markdown]
# ### 2. Acceso a los elementos de un diccionario

# %% [markdown]
# Al contrario que las listas o las tuplas, los diccionarios no se acceden utilizando un índice. Los valores se acceden utilizando el nombre de la clave entre corchetes `[]`.

# %%
dic = {
    "nombre":"yimmy",
    "apellido":"Eman",
    "pais": "venezuela"
}

# %%
dic['nombre']

# %%
dic['apellido']

# %%
dic['pais']

# %%
dic[0]

# %% [markdown]
# Una de las cosas importantes que debemos tener en cuenta es que podemos utilizar cualquier objeto inmutable como clave de un diccionario, esto incluye números, strings, tuplas...

# %%
dic2 = {
    0: "cero",
    1: "uno",
    2: "dos",
    3: "tres"
}

# %%
dic2[0]

# %%
dic2[3]

# %%
dic3 = {
    ("uno", 1): "one",
    ("dos", 2): "two",
    ("tres", 3): "three",
    ("solo",) : "solo"
}

# %%
dic3[("uno", 1)]

# %%
dic3["dos", 2]

# %%
dic3[("solo",)]

# %% [markdown]
# ### 3. Elementos de un diccionario

# %% [markdown]
# Los diccionarios son estructuras que **pueden ser modificadas** y que **no respetan el orden** de los elementos, esto es como consecuencia de que sus elementos no se acceden a través de un índice númerico que determina su posición sino a través de una clave.

# %%
dic = {
    "Ciudad":"Caracas",
    "Nombre":"Yimmy",
    "Apellido":"Eman",
    "Pais":"Venezuela"
}

# %%
dic["Nombre"] = "Juan"

# %%
dic["Apellido"] = "Perez"

# %%
print(dic)
# Out:
# {'Ciudad': 'Caracas', 'Nombre': 'Juan', 'Apellido': 'Perez', 'Pais': 'Venezuela'}

# %% [markdown]
# Una cosa interesante sobre los diccionarios es que podemos añadir nuevos elementos en la estructura cuando lo necesitemos.

# %%
print(dic)
# Out:
# {'Ciudad': 'Caracas', 'Nombre': 'Juan', 'Apellido': 'Perez', 'Pais': 'Venezuela'}

# %%
dic["Edad"] = 30

# %%
dic["Nacionalidad"] = "Venezolana"

# %%
print(dic)
# Out:
# {'Ciudad': 'Caracas', 'Nombre': 'Juan', 'Apellido': 'Perez', 'Pais': 'Venezuela', 'Edad': 30, 'Nacionalidad': 'Venezolana'}

# %%
dic[("API", "KEY")] = "SSKJOJSAOJSAO"

# %%
dic
# Out:
# {'Ciudad': 'Caracas',
#  'Nombre': 'Juan',
#  'Apellido': 'Perez',
#  'Pais': 'Venezuela',
#  'Edad': 30,
#  'Nacionalidad': 'Venezolana',
#  ('API', 'KEY'): 'SSKJOJSAOJSAO'}

# %% [markdown]
# Como podéis observar en el ejemplo anterior, los diccionarios permiten asignar diferentes tipos de datos a los valores que referencian las claves. Podemos asignar datos de cualquier tipo: números, strings, listas, tuplas... o incluso diccionarios.

# %%
dic2 = {
    "num":10,
    "str":"Hola mundo",
    "lista":[1, 2, 3, 4],
    "tupla":(1, 2, 3, 4),
    "dic":{"k1":"clave1", "k2":"clave2"}
}

# %%
dic2["dic"]["k2"]
# Out:
# 'clave2'

# %% [markdown]
# Las claves del diccionario tampoco tienen que se del mismo tipo de dato.

# %%
dic3 = {
    1:"primer valor",
    "dos":"segundo valor",
    ("tres",):"tercer valor"
}

# %%
dic3[1]

# %%
dic3["dos"]

# %%
dic3[("tres",)]

# %% [markdown]
# **La restricción más importante que debemos de tener en cuenta cuando utilizamos diccionarios, es que no puede haber dos claves con el mismo nombre**

# %%
dic4 = {
    "key":"value1",
    "key":"value2"
}

# %%
dic4
# Out:
# {'key': 'value2'}

# %% [markdown]
# ### 4. Operaciones con diccionarios

# %% [markdown]
# Al igual que con las listas y el resto de tipos de datos complejos, podemos utilizar algunos de los operadores presentados en el tema anterior con los diccionarios.

# %%
x="hola"
# Out:
# True

# %%
w= "hola"

# %%
x==w
# Out:
# True

# %%
id(x)
# Out:
# 1935622741872

# %%
id(w)
# Out:
# 1935622741872

# %%
hello="hola"
id(hello)
# Out:
# 1935622741872

# %%
dic1 = {
    "key1": "value1",
    "key2": "value2"
}

# %%
dic2 = {
    "key3": "value3",
    "key4": "value4"
}

# %%
dic1 is dic2
# Out:
# False

# %%
dic1 == dic2
# Out:
# False

# %%
dic1 == dic1
# Out:
# True

# %%
dic1 is dic1
# Out:
# True

# %%
dic1 + dic2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 dic1 + dic2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dict1
