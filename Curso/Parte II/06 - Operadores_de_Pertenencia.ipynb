# %% [markdown]
# # Operadores de pertenencia

# %% [markdown]
# ### ¿Cuáles son los operadores de pertenencia?

# %% [markdown]
# Los operadores de pertenencia se utilizan para evaluar sin una sequencia se encuentra presente en un objeto.

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Operador</th>
# <th>Ejemplo</th>
# <th>Significado</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>in</code></td>
# <td><code>x in y</code></td>
#     <td><code>True</code> si la secuencia <code>y</code> se<br>encuentra presente en <code>x</code></td>
# </tr>
# <tr>
# <td><code>not in</code></td>
# <td><code>x not in y</code></td>
# <td><code>True</code> si la secuencia <code>y</code> no se<br>encuentra presente en <code>x</code></td>
# </tr>
# </tbody>
# </table>

# %%
text = "Cadena de texto"

# %%
"texto" in text
# Out:
# True

# %%
"hola" in text
# Out:
# False

# %%
"a" in text
# Out:
# True

# %%
num = 3500

# %%
3 in num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/yimmyeman/Cursos/Curso Python Presencial/Parte II/06 - Operadores_de_Pertenencia.ipynb Celda 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yimmyeman/Cursos/Curso%20Python%20Presencial/Parte%20II/06%20-%20Operadores_de_Pertenencia.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> 3 in num
#
# TypeError: argument of type 'int' is not iterable

# %%
num = "12345"

# %%
"1" in num
# Out:
# True

# %%
lista = [1,2,3,4]

# %%
lista
# Out:
# [1, 2, 3, 4]

# %%
1 in lista
# Out:
# True

# %%
"1" not in lista
# Out:
# True
